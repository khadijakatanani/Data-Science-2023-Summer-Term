# %% [markdown]
# <a href="https://colab.research.google.com/github/khadijakatanani/Data-Science-2023-Summer-Term/blob/Weekly-Materials/DS_Week_4_20_07_2023_Seminar_Notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Rain in Australia Dataset

# %% [markdown]
# The following topics are covered in this tutorial:
#
# - Downloading a real-world dataset from Kaggle
# - Exploratory data analysis and visualization

# %% [markdown]
# The [Rain in Australia dataset](https://kaggle.com/jsphyg/weather-dataset-rattle-package) contains about 10 years of daily weather observations from numerous Australian weather stations. Here's a small sample from the dataset:
# >
# > ![](https://i.imgur.com/5QNJvir.png)

# %% [markdown]
# ## 1. Load the data from `weatherAUS.csv` using Pandas.

# %%
import pandas as pd
import numpy as np

# %%
from google.colab  import files
file = files.upload()
# Out:
#      <input type="file" id="files-f0a4264e-32d2-4845-8b9f-eaf48d3c61a2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f0a4264e-32d2-4845-8b9f-eaf48d3c61a2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('./weatherAUS.csv')   # place your code here

# %%
df.index = df['Date']

# %%
df
# Out:
#                   Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# Date
# 2008-12-01  2008-12-01   Albury     13.4     22.9       0.6          NaN
# 2008-12-02  2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2008-12-03  2008-12-03   Albury     12.9     25.7       0.0          NaN
# 2008-12-04  2008-12-04   Albury      9.2     28.0       0.0          NaN
# 2008-12-05  2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...                ...      ...      ...      ...       ...          ...
# 2017-06-21  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 2017-06-22  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 2017-06-23  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 2017-06-24  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 2017-06-25  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#             Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %% [markdown]
# ## 2. Develop code to get the following output

# %%
df.info() # place your code here
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 145460 entries, 2008-12-01 to 2017-06-25
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %% [markdown]
# The dataset contains over ... rows and ... columns. <br>The dataset contains ... columns. (does it contain date, numeric or categorical data type, or all><br>
# The following columns contain missing values:
#
# "column name": "number of missing values"

# %% [markdown]
# ## 3.
# ### It might be a good idea to discard the rows where the value of `RainTomorrow` or `RainToday` is missing to make our analysis and modeling simpler (since one of them is the target variable, and the other is likely to be very closely related to the target variable).

# %%
df.dropna(subset=['RainTomorrow', 'RainToday'], inplace=True)
df['RainTomorrow'].isna().sum()
# Out:
# 0

# %% [markdown]
# ## Exploratory Data Analysis and Visualization
#
# Before training a machine learning model, its always a good idea to explore the distributions of various columns and see how they are related to the target column. Let's explore and visualize the data using the Plotly, Matplotlib and Seaborn libraries. Follow these tutorials to learn how to use these libraries:
#
# 1.   https://jovian.ai/aakashns/python-matplotlib-data-visualization
# 2.   https://jovian.ai/aakashns/interactive-visualization-plotly
# 3.   https://jovian.ai/aakashns/dataviz-cheatsheet

# %%
# !pip install plotly matplotlib seaborn --quiet

# %%
import plotly.express as px
# The plotly.express module (usually imported as px ) contains functions that can create entire figures at once, and is referred to as Plotly Express or PX. (https://plotly.com/python/plotly-express/)
# Plotly express is a high-level data visualization package that allows you to create interactive plots with very little code.
# It is built on top of Plotly Graph Objects, which provides a lower-level interface for developing custom visualizations.
# (https://www.datacamp.com/cheat-sheet/plotly-express-cheat-sheet#:~:text=Plotly%20express%20is%20a%20high,interface%20for%20developing%20custom%20visualizations.)

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (10, 6)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %% [markdown]
# ### Histograms

# %%
# histogram way 1
# px.histogram(<dataframe name>, x=?, title=?, color='RainToday')


# Question:
# What locations are more rainy than others?
# What locations are drier than others?

# histogram way 2
# fig = plt.figure(figsize = (10,6))
# ax = fig.gca() # get current axis

# For All Numeric Fields to Check the Gaussian distribution
# data.hist(ax = ax);

# For A Single Numeric Field
# data["wheel-base"].hist(ax = ax)


# histogram way 3
# Creating a single histogram with matplotlib library
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize =(7, 5))
# # subplots method provides a way to plot multiple plots on a single figure

plt.hist(df["MaxTemp"], bins = [i for i in range(0, 40, 5)])



# histogram way 4
# Creating multiple histograms with matplotlib library

# # With the subplot() function you can draw multiple plots in one figure
# # you define the # of rows, # of columns, and finally where your histogram will be located

# # first histogram will be for the Fare column
# plt.subplot(1,2,1)
# plt.ylabel("Days with tempreture")
# plt.xlabel("Temperaure in degree C")
# plt.title = "Maximum temperature"
# plt.hist(df["MaxTemp"], bins = [i for i in range(0, 40, 5)]) # bins parameter defines the # of bins in the histogram, each 25 unit wide

# # # second histogram will be for the Age column
# plt.subplot(1,2,2)
# plt.ylabel("Days with certain humidity")
# plt.xlabel("Humidity at 9 pm")
# plt.title = "Outlier Detection for Age Variable"
# plt.hist(df["Humidity9am"], bins = [i for i in range(0, 101, 5)]) # bins define the # of bins in the histogram, each 25 unit wide

# # to adjust spacing
plt.tight_layout()
# # The tight_layout() method automatically maintains the proper space between subplots.

plt.show()

# %% [markdown]
# ![newplot.png](data:image/png;base64,...)

# %%
px.histogram(<dataframe name>, x=?, title=?, color='RainTomorrow')

# %% [markdown]
# ![newplot (1).png](data:image/png;base64,...)

# %%
# your turn
px.histogram(...)

# %% [markdown]
# ![newplot (2).png](data:image/png;base64,...)

# %% [markdown]
# ### Scatter Plot

# %%
px.scatter(df.sample(2000),
           title='Temp 3pm vs Humidity 3pm',
           x='Temp3pm',
           y='Humidity3pm',
           color='RainTomorrow')

# try with the whole dataset
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ![newplot (3).png](data:image/png;base64,...)

# %%
px.scatter(df.sample(2000),
           title='Temp 3pm vs Humidity 3pm',
           x='Temp3pm',
           y='Humidity3pm',
           color='RainTomorrow')


# way 2

plt.scatter(df['Temp3pm'], df['Humidity3pm'], color = "blue")
plt.xlabel('Temperature at 3pm')
plt.ylabel('Humidity at 3pm')
plt.title('Temp va Humidity')

# way 3
plt.figure(figsize = (15,6))
sns.relplot(x = df['Temp3pm'], y = df['Humidity3pm'], kind = "scatter")
# plt.show();

# way 4
sns.scatterplot(x = 'Temp3pm', y ='Humidity3pm' , data = df,  marker = ">", hue = "RainToday", style = "Location") # try different markers: https://www.w3schools.com/python/matplotlib_markers.asp
plt.xlim([50, 350])
plt.ylim([85, 125])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-749fa53d5a9a> in <cell line: 13>()
#      11 plt.xlabel('Temperature at 3pm')
#      12 plt.ylabel('Humidity at 3pm')
# ---> 13 plt.title('Temp va Humidity')
#      14
#      15 # way 3
#
# TypeError: 'str' object is not callable

# %%
help(plt.title())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-d6a207d9a604> in <cell line: 1>()
# ----> 1 help(plt.title())
#
# TypeError: 'str' object is not callable

# %% [markdown]
# ![newplot (4).png](data:image/png;base64,...)

# %% [markdown]
# ### Pie Chart

# %%
# pie chart 1

labels = df[<column_name>].unique()
sizes =  df[<column_name>].value_counts().values  # Values representing the sizes of each category

# Create the pie chart using matplotlib
fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)

# Optional: Customize the chart appearance using seaborn
sns.set_style("white")  # Set a white background
ax.axis('equal')  # Ensure the pie chart is circular

# Display the chart
plt.show()


# pie chart 2
# rain_tomorrow = data.groupby("RainTomorrow").size()
# rain_tomorrow_count = rain_tomorrow.tolist()

# plt.figure(figsize = (15,6))
# plt.pie(rain_tomorrow_count, labels = ["Yes", "No"], autopct="%.2f%%", textprops = {"fontsize": 14})
# plt.title("Distribuition of ...", fontsize = 16)

# plt.tight_layout()
# plt.show()

# %% [markdown]
# ### JointPlot

# %%
# jointplot

sns.jointplot(x = df[<column_name>], y = df[<column_name>])
plt.show()

# %% [markdown]
# ### Heatmaps

# %%
# heatmap 1

sns.set(font_scale = 0.5)
plt.figure(figsize=(20,20), dpi =100)
sns.heatmap(corr,annot=True,fmt=".2f", linewidth=.01)
plt.title("Correlation of Features")
plt.show()

# heatmap 2
# import warnings
# warnings.filterwarnings("ignore")

# corr = df.corr(method = 'pearson')
# corr.style.background_gradient(cmap='coolwarm').set_precision(2)

# %% [markdown]
# ### Box Plots

# %%
# 1. box plot with a df plot method
df["Fare"].plot(kind = "box", vert=False)
# <interpret the graph>
# <we will have to deal with those outliers>


# 2. box plot with a seaborn boxplot method
# import seaborn as sns
# sns.boxplot(df['Fare'], orient  = "h")
# # <interpret the graph>
